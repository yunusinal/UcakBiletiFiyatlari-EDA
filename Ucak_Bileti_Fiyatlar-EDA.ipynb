# %%
import pandas as pd
import numpy as np 

import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %%
dataB = pd.read_csv("business.csv")
dfb= pd.DataFrame(dataB)
dfb["class"]="business"
dfb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 93487 entries, 0 to 93486
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   date        93487 non-null  object
#  1   airline     93487 non-null  object
#  2   ch_code     93487 non-null  object
#  3   num_code    93487 non-null  int64
#  4   dep_time    93487 non-null  object
#  5   from        93487 non-null  object
#  6   time_taken  93487 non-null  object
#  7   stop        93487 non-null  object
#  8   arr_time    93487 non-null  object
#  9   to          93487 non-null  object
#  10  price       93487 non-null  object
#  11  class       93487 non-null  object
# dtypes: int64(1), object(11)
# memory usage: 8.6+ MB

# %%
dataE = pd.read_csv("economy.csv")
dfe= pd.DataFrame(dataE)
dfe["class"]="economy"
dfe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 206774 entries, 0 to 206773
# Data columns (total 12 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   date        206774 non-null  object
#  1   airline     206774 non-null  object
#  2   ch_code     206774 non-null  object
#  3   num_code    206774 non-null  int64
#  4   dep_time    206774 non-null  object
#  5   from        206774 non-null  object
#  6   time_taken  206774 non-null  object
#  7   stop        206774 non-null  object
#  8   arr_time    206774 non-null  object
#  9   to          206774 non-null  object
#  10  price       206774 non-null  object
#  11  class       206774 non-null  object
# dtypes: int64(1), object(11)
# memory usage: 18.9+ MB

# %% [markdown]
# # 1. **Verileri Birleştirme ve Temizleme**

# %%
# business ve economy class verilerini birleştirme 
# clean_dataset olsa bile kendim birleştirip veriler üzerinde düzenleme işlemlerini yapmak istedim.

df = pd.concat([dfe, dfb]).drop_duplicates(keep=False) 
df
# Out:
#              date   airline ch_code  num_code dep_time     from time_taken  \
# 0      11-02-2022  SpiceJet      SG      8709    18:55    Delhi    02h 10m
# 1      11-02-2022  SpiceJet      SG      8157    06:20    Delhi    02h 20m
# 2      11-02-2022   AirAsia      I5       764    04:25    Delhi    02h 10m
# 3      11-02-2022   Vistara      UK       995    10:20    Delhi    02h 15m
# 4      11-02-2022   Vistara      UK       963    08:50    Delhi    02h 20m
# ...           ...       ...     ...       ...      ...      ...        ...
# 93482  31-03-2022   Vistara      UK       822    09:45  Chennai    10h 05m
# 93483  31-03-2022   Vistara      UK       826    12:30  Chennai    10h 25m
# 93484  31-03-2022   Vistara      UK       832    07:05  Chennai    13h 50m
# 93485  31-03-2022   Vistara      UK       828    07:00  Chennai    10h 00m
# 93486  31-03-2022   Vistara      UK       822    09:45  Chennai    10h 05m
#
#                                                     stop arr_time         to  \
# 0                                              non-stop     21:05     Mumbai
# 1                                              non-stop     08:40     Mumbai
# 2                                              non-stop     06:35     Mumbai
# 3                                              non-stop     12:35     Mumbai
# 4                                              non-stop     11:10     Mumbai
# ...                                                  ...      ...        ...
# 93482  1-stop\n\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t...    19:50  Hyderabad
# 93483  1-stop\n\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t...    22:55  Hyderabad
# 93484  1-stop\n\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t...    20:55  Hyderabad
# 93485  1-stop\n\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t...    17:00  Hyderabad
# 93486  1-stop\n\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t...    19:50  Hyderabad
#
#         price     class
# 0       5,953   economy
# 1       5,953   economy
# 2       5,956   economy
# 3       5,955   economy
# 4       5,955   economy
# ...       ...       ...
# 93482  69,265  business
# 93483  77,105  business
# 93484  79,099  business
# 93485  81,585  business
# 93486  81,585  business
#
# [300257 rows x 12 columns]

# %%
## ch_code ile num_code sütunlarını birleştirip flight sütununa atama
df["flight"] = df["ch_code"].str.cat(df["num_code"].astype(str), sep="-") 
df["flight"]
# Out:
# 0        SG-8709
# 1        SG-8157
# 2         I5-764
# 3         UK-995
# 4         UK-963
#           ...
# 93482     UK-822
# 93483     UK-826
# 93484     UK-832
# 93485     UK-828
# 93486     UK-822
# Name: flight, Length: 300257, dtype: object

# %%
df=df.drop(columns=["ch_code","num_code"])

# %%
df.rename(columns={"from":"dep_city","to":"arrival_city"},inplace=True)

# %%
df["date"] = pd.to_datetime(df["date"], dayfirst=True)

# %%
today=df['date'].sort_values().values[0]
today
# Out:
# np.datetime64('2022-02-11T00:00:00.000000000')

# %%
df["days_left"] = (df["date"]- today ).dt.days #days_left sütununa kaç gün kaldığını yazdırmak

# %%
df.drop(columns="date",inplace=True)

# %%
# sütun sıralamasını ayarlama
columns= list(df.columns)
columns = ['airline','flight','dep_city','dep_time','time_taken','stop','arr_time', 'arrival_city','class','price','days_left']
df= df[columns]
df
# Out:
#         airline   flight dep_city dep_time time_taken  \
# 0      SpiceJet  SG-8709    Delhi    18:55    02h 10m
# 1      SpiceJet  SG-8157    Delhi    06:20    02h 20m
# 2       AirAsia   I5-764    Delhi    04:25    02h 10m
# 3       Vistara   UK-995    Delhi    10:20    02h 15m
# 4       Vistara   UK-963    Delhi    08:50    02h 20m
# ...         ...      ...      ...      ...        ...
# 93482   Vistara   UK-822  Chennai    09:45    10h 05m
# 93483   Vistara   UK-826  Chennai    12:30    10h 25m
# 93484   Vistara   UK-832  Chennai    07:05    13h 50m
# 93485   Vistara   UK-828  Chennai    07:00    10h 00m
# 93486   Vistara   UK-822  Chennai    09:45    10h 05m
#
#                                                     stop arr_time  \
# 0                                              non-stop     21:05
# 1                                              non-stop     08:40
# 2                                              non-stop     06:35
# 3                                              non-stop     12:35
# 4                                              non-stop     11:10
# ...                                                  ...      ...
# 93482  1-stop\n\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t...    19:50
# 93483  1-stop\n\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t...    22:55
# 93484  1-stop\n\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t...    20:55
# 93485  1-stop\n\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t...    17:00
# 93486  1-stop\n\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t...    19:50
#
#       arrival_city     class   price  days_left
# 0           Mumbai   economy   5,953          0
# 1           Mumbai   economy   5,953          0
# 2           Mumbai   economy   5,956          0
# 3           Mumbai   economy   5,955          0
# 4           Mumbai   economy   5,955          0
# ...            ...       ...     ...        ...
# 93482    Hyderabad  business  69,265         48
# 93483    Hyderabad  business  77,105         48
# 93484    Hyderabad  business  79,099         48
# 93485    Hyderabad  business  81,585         48
# 93486    Hyderabad  business  81,585         48
#
# [300257 rows x 11 columns]

# %% [markdown]
# ## 1.1 Temizleme Fonksiyonları

# %%
# stop değerlerini Temizleme fonksiyonu
def clean_stop_value(value):
    if "non-stop" in value:
        return "non-stop"
    elif "2+-stop" in value:
        return "2+"
    elif "1-stop" in value:
        return "1"
    else:
        return "unknown"

df['stop'] = df['stop'].apply(clean_stop_value)

# %%
# bekleme zamanını floata çeviren fonksiyon 
def time_to_float(time_str):
    # Saat ve dakika değerlerini ayır
    time_str = time_str.replace(" ", "") #boşlukları kaldırıyoruz
    hours = time_str.split('h')[0]  # out: ["13" ," 50m"]
    ## bazı saat değerleri ondalıklı olarak verilmiş 1.02h  gibi bunları direkt ekliyoruz
    ## clean_Dataset te bu verileri çıkartmışlar ben eklemek istedim. 
    if "." in hours:
        return hours
    else:
        minutes = int(time_str.split('h')[1].split('m')[0]) # [" 50","m"] şeklinde oluyor bunun ilk indexini alıp inte çeviriyoz. 
        return int(hours) +(minutes / 60)
    # Float cinsine çevir (dakikaları saatlere çevirip ekle)
       
df["time_taken"]=df["time_taken"].apply(time_to_float)

# %%
def deleteComma(comma):
    comma=comma.replace(",","")
    return comma
    
df["price"]=df["price"].apply(deleteComma)

# %%
# kategorik ama sayısal değerde olan sütunları numeric veri tipine çeviriyorum
df["price"]= pd.to_numeric(df["price"])
df["time_taken"]= pd.to_numeric(df["time_taken"])

# %%
#veri setinde 300 000 veri vardı bunlardan rastgele 100 000 tanesini alıyoruz.

df_sample = df.sample(n=100000,random_state=37)
df_sample.reset_index(inplace=True,drop=True)

# %% [markdown]
# ## 1.2 Eksik veri oluşturma

# %%
# Veri setinde rasgele eksik veriler oluşturalım.

import random

def add_random_missing_values(dataframe: pd.DataFrame,
                              missing_rate: float = 0.05,
                              seed: random = 42) -> pd.DataFrame:
    """Turns random values to NaN in a DataFrame.
    
    To use this function, you need to import pandas, numpy and random libraries.

    Args:
        dataframe (pd.DataFrame): DataFrame to be processed.
        missing_rate (float): Percentage of missing value rate in float format. Defaults 0.05

    
    """
    # Get copy of dataframe
    df_missing = dataframe.copy()

    # Obtain size of dataframe and number total number of missing values
    df_size = dataframe.size
    num_missing = int(df_size * missing_rate)
    
    # Set seed
    if seed:
        random.seed(seed)

    # Get random row and column indexes to turn them NaN
    for _ in range(num_missing):
        row_idx = random.randint(0, dataframe.shape[0] - 1)
        col_idx = random.randint(0, dataframe.shape[1] - 1)

        df_missing.iat[row_idx, col_idx] = np.nan
        
    return df_missing

df = add_random_missing_values(dataframe = df,
                               missing_rate = 0.03)

# %% [markdown]
# # 2. Keşifsel Veri Analizi | EDA(Exploratory Data Analysis) |

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 300257 entries, 0 to 93486
# Data columns (total 11 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   airline       291469 non-null  object
#  1   flight        291274 non-null  object
#  2   dep_city      291243 non-null  object
#  3   dep_time      291436 non-null  object
#  4   time_taken    291394 non-null  float64
#  5   stop          291503 non-null  object
#  6   arr_time      291331 non-null  object
#  7   arrival_city  291286 non-null  object
#  8   class         291451 non-null  object
#  9   price         291452 non-null  float64
#  10  days_left     291309 non-null  float64
# dtypes: float64(3), object(8)
# memory usage: 27.5+ MB

# %%
df.head(10)
# Out:
#     airline   flight dep_city dep_time  time_taken      stop arr_time  \
# 0  SpiceJet  SG-8709    Delhi    18:55    2.166667  non-stop    21:05
# 1  SpiceJet  SG-8157    Delhi    06:20    2.333333  non-stop    08:40
# 2   AirAsia   I5-764    Delhi    04:25    2.166667  non-stop    06:35
# 3   Vistara   UK-995    Delhi    10:20         NaN  non-stop      NaN
# 4   Vistara   UK-963    Delhi    08:50    2.333333  non-stop    11:10
# 5   Vistara   UK-945    Delhi    11:40    2.333333  non-stop    14:00
# 6   Vistara   UK-927    Delhi    09:30    2.083333  non-stop    11:35
# 7   Vistara   UK-951    Delhi    14:20    2.166667       NaN    16:30
# 8  GO FIRST   G8-334    Delhi    08:00    2.166667  non-stop    10:10
# 9  GO FIRST   G8-336    Delhi    14:20    2.250000  non-stop    16:35
#
#   arrival_city    class   price  days_left
# 0       Mumbai  economy  5953.0        0.0
# 1       Mumbai  economy  5953.0        0.0
# 2       Mumbai  economy  5956.0        0.0
# 3       Mumbai  economy  5955.0        0.0
# 4       Mumbai  economy  5955.0        0.0
# 5       Mumbai  economy  5955.0        0.0
# 6       Mumbai  economy  6060.0        0.0
# 7       Mumbai  economy  6060.0        0.0
# 8       Mumbai  economy  5954.0        0.0
# 9       Mumbai  economy  5954.0        0.0

# %%
df.describe().T
# Out:
#                count          mean           std          min          25%  \
# time_taken  291394.0     12.221517      7.195009     0.833333     6.833333
# price       291452.0  20895.904914  22703.164400  1105.000000  4783.000000
# days_left   291309.0     25.000508     13.558940     0.000000    14.000000
#
#                 50%           75%            max
# time_taken    11.25     16.166667      49.833333
# price       7425.00  42521.000000  123071.000000
# days_left     25.00     37.000000      48.000000

# %% [markdown]
# ## 2.0 Eksik Değerlerin Analizi

# %%
df.isna().sum()
# Out:
# airline         8788
# flight          8983
# dep_city        9014
# dep_time        8821
# time_taken      8863
# stop            8754
# arr_time        8926
# arrival_city    8971
# class           8806
# price           8805
# days_left       8948
# dtype: int64

# %%
# verilerin NaN olduğu değerlere baktığımızda çoğu sütundaki verileri tahmin etmemiz neredeyse mümkün olmadığından 
# burdaki NaN değer olan satırları veri setinden kaldırıyorum
df.dropna(subset=["airline","flight","dep_city","dep_time","time_taken","arr_time","arrival_city","class","days_left"], inplace=True)

# %%
df["stop"].value_counts()
# Out:
# stop
# 1           185745
# non-stop     26676
# 2+            9853
# Name: count, dtype: int64

# %%
# durak değerlerine baktığımızda en çok tekrar eden değer olan 1 ile dolduruyorum NaN değerleri
df["stop"].fillna(df["stop"].value_counts().index[0],inplace=True)

# %%
# fiyat sütunundaki NaN değerleri "ortalama" değeriyle dolduruyorum.
df["price"].fillna(df["price"].mean(),inplace=True)

# %%
df.isna().sum()
# Out:
# airline         0
# flight          0
# dep_city        0
# dep_time        0
# time_taken      0
# stop            0
# arr_time        0
# arrival_city    0
# class           0
# price           0
# days_left       0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 228985 entries, 0 to 93484
# Data columns (total 11 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   airline       228985 non-null  object
#  1   flight        228985 non-null  object
#  2   dep_city      228985 non-null  object
#  3   dep_time      228985 non-null  object
#  4   time_taken    228985 non-null  float64
#  5   stop          228985 non-null  object
#  6   arr_time      228985 non-null  object
#  7   arrival_city  228985 non-null  object
#  8   class         228985 non-null  object
#  9   price         228985 non-null  float64
#  10  days_left     228985 non-null  float64
# dtypes: float64(3), object(8)
# memory usage: 21.0+ MB

# %% [markdown]
# ## 2.1 Sayısal Değerlerin Analizi

# %%
fig, axes = plt.subplots(1, 3, figsize=(15, 5)) # fig:ana figur  axes: alt grafiklerin eksenleri axes[0],axes[1] şeklinde erişilir
colors = sns.color_palette('Blues', 3) #Seaborn'un "Blues" renk paletinden 3 renk alır.

sns.histplot(df['time_taken'], ax=axes[0],color=colors[1],kde=True, bins=20) # kde: yoğunluk eğrisi (Kernel Density Estimation) ekler.
axes[0].set_title('Gecen Süre')
sns.histplot(df['days_left'], ax=axes[1], kde=True, color=colors[1], bins=20)
axes[1].set_title('Ucagin Kalkmasına Kalan Gün')

sns.histplot(df['price'], ax=axes[2], kde=True, color=colors[1], bins=15)
axes[2].set_title('Fiyat')

plt.tight_layout()
plt.show()

# %% [markdown]
# > - Gerkçekleşen uçuşların çoğu 5 saatten fazla sürmektedir.
# > - Uçuşların fiyatlarının yaklaşık %60'ı 15000'in altındadır .

# %%
fig, axes = plt.subplots(1, 2, figsize=(20, 8))  # 1 satır 2 tane sütun

# Sınıf dağılımı Pasta grafiği
axes[0].pie(
    labels=df["class"].value_counts().index,
    x=df["class"].value_counts().values,
    explode=[0, 0.03],  #  pastadaki değerler arasındaki boşluk
    autopct='%1.1f%%')

axes[0].set_title("Sınıf Dağılımı")


gb1 = df.groupby(["airline","class"])[["price"]].mean()
gb1.plot(kind="barh", stacked=True,ax= axes[1])

axes[1].set_title("Havayolu Şirketi ve Sınıfa göre Ortalama Fiyatlar")
axes[1].set_ylabel("")
axes[1].set_xlabel("Fiyat")


plt.tight_layout()  # Adjust layout for better spacing
#plt.title('Sınıf Dağılımı')
plt.show()

# %% [markdown]
# > - Gerçekleşen uçuşların büyük bir çoğunluğu ekonomi sınıfında gerçekleşmiş.
# > - Ekonomi sınıfındaki uçuşlarda Havayolu şirketleri benzer fiyatlar vermektedir.Fakat en düşük fiyat Trujet firmasıdır.
# > - Business sınıfındaki uçuşlarda  "Vistara" havayolu "Air_india" havayolundan daha pahalıdır.

# %%
# sayısal değerler arasında bir korelasyon var mı diye heatmape bakıyoruz.  
plt.figure(figsize = (10, 7))
sns.heatmap( df[['price', 'time_taken', 'days_left',]].corr(), annot = True, cmap = "coolwarm")
plt.show()

# %% [markdown]
# > - Numerik değerler arasında herhangi anlamlı bir korelasyon yoktur.

# %% [markdown]
# ## ---Şehirlere Göre Fiyat Dağılımı

# %%
# Şehirlere göre fiyat dağılımı
city_prices = df.groupby('dep_city')['price'].mean().sort_values()

plt.figure(figsize=(10, 6))
sns.barplot(x=city_prices.index, y=city_prices.values, palette='viridis')
plt.title('Şehirlere Göre Ortalama Fiyat')
plt.xlabel('Şehir')
plt.ylabel('Ortalama Fiyat')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# > - Şehirlere göre ortalama fiyatlar birbirine yakın değerlerdedir.

# %% [markdown]
# ## ---Havayolu Bazında Ortalama Uçuş Süresi

# %%
# havayolunun uçuş süresi üzerindeki etkisi
plt.figure(figsize=(12, 6))
sns.boxplot(x='airline', y='time_taken', data=df, palette='Set1')
plt.title('Havayoluna Göre Uçuş Süresi Dağılımı')
plt.xlabel('Havayolu')
plt.ylabel('Uçuş Süresi (Saat)')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# > - StarAir, Trujet, Indigo görece daha kısa uçuş süreleri sunmaktadır.

# %% [markdown]
# ## ? Uçuştan 1-2 gün önce alınan biletler daha mı ucuzdur?

# %%
gb2 = df.groupby("days_left")[["price"]].mean()

sns.barplot(x=gb2.index,y=gb2["price"],palette='viridis')
# X ekseninde her 5. indeksi göstermek için kullandık.  [0,5,10,15,20,25,30,50] şeklinde kendimiz de verebilirdik. 
plt.xticks(np.arange(0,len(gb2),step=5), ha='right')  

plt.tight_layout()  
plt.show()

# %% [markdown]
# > - Görüldüğü üzere Uçak biletleri son hafta içinde en yüksek fiyatında satılıyor fakat son gün fiyatı düşmeye başlıyor.

# %%
plt.figure(figsize=(12, 6))
sns.histplot(x=df["days_left"],kde=True)

plt.xticks(df["days_left"].unique(),ha='right')

plt.tight_layout()
plt.show()

# %% [markdown]
# > - Çoğu müşteri biletlerini en az 1 hafta önce almayı tercih ediyor.

# %% [markdown]
# ## ---Uçak bileti fiyatlarının kalkış ve varış zamanına göre değişimi

# %%
df['dep_time'] = pd.to_datetime(df['dep_time'], errors='coerce')
df['arr_time'] = pd.to_datetime(df['arr_time'], errors='coerce')

def categorize_time(dep_time):
    hour = dep_time.hour 
    if 5 <= hour < 7:
        return 'Sabah Erken(5-7)'
    elif 7 <= hour < 12:
        return 'Sabah(7-12)'
    elif 12 <= hour < 16:
        return 'Öglen(12-16)'
    elif 16 <= hour < 20:
        return 'Akşam(16-20)'
    elif 20 <= hour < 24:
        return 'Gece(20-24)'
    else:
        return 'Gece Yarısı(24-5)'

# Yeni bir sütun ekleyerek kategorilere ayırıyoruz
df['dep_time_category'] = df['dep_time'].apply(categorize_time)
df['arr_time_category'] = df['arr_time'].apply(categorize_time)

# %%
gbd = df.groupby(["dep_time_category","arr_time_category"])[["price"]].mean()
gbd.head()
# Out:
#                                             price
# dep_time_category arr_time_category
# Akşam(16-20)      Akşam(16-20)       24571.853895
#                   Gece Yarısı(24-5)   9387.442722
#                   Gece(20-24)        16336.409932
#                   Sabah Erken(5-7)    8915.879386
#                   Sabah(7-12)        26540.456769

# %%
idx = list(df["dep_time_category"].value_counts().index)
fig , ax = plt.subplots(3,2,figsize=(12, 10))

for row in range(3):
    for col in range(2):
        plot = idx.pop()
#         plt.title(plot)
        sns.barplot(y= gbd.loc[plot].index, x=gbd.loc[plot]["price"], ax= ax[row][col], palette='Blues').set(title = plot)
        
        
plt.tight_layout()
plt.show()

# %% [markdown]
# > **Görüldüğü üzere sabah(7-12) uçak biletlerini ortlama ücreti daha yüksektir.
#   En düşük ücret ortalama olarak gece(24-5) binilen uçaklardır.**

# %% [markdown]
# ## ---Kalkış ve Varış yerine göre Fiyatların değişimi

# %%
gb3= df.groupby(["dep_city","arrival_city"])[["price"]].mean()
gb3.head()
# Out:
#                                price
# dep_city  arrival_city
# Bangalore Chennai       23322.074220
#           Delhi         17773.226358
#           Hyderabad     21092.717111
#           Kolkata       23337.943590
#           Mumbai        23114.024054

# %%
idx = list(df["dep_city"].value_counts().index)
fig , ax = plt.subplots(3,2,figsize=(12, 10))

for row in range(3):
    for col in range(2):
        plot = idx.pop()
#         plt.title(plot)
        sns.barplot(y= gb3.loc[plot].index, x=gb3.loc[plot]["price"], ax= ax[row][col], palette='coolwarm').set(title = plot)
        
        
plt.tight_layout()
plt.show()

# %% [markdown]
# > - **A -> B veya B->A ya herhangi bir olağandışı şekilde fiyatlar değişmemiş.**
